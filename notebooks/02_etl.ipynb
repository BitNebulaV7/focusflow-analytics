# %%
import pandas as pd

events = pd.read_csv("../data/raw/events.csv")
app_events = pd.read_csv("../data/raw/app_events.csv")
devices = pd.read_csv("../data/raw/phone_brand_device_model.csv")

print("Event Shapes:", events.shape)
print("App Events shape:", app_events.shape) 
print("Devices shape:", devices.shape)

print("Events columns:", events.columns.tolist())
print("App Events:", app_events.columns.tolist())
print("Devices:", devices.columns.tolist())
# Out:
# Event Shapes: (3252950, 5)
# App Events shape: (32473067, 4)
# Devices shape: (187245, 3)
# Events columns: ['event_id', 'device_id', 'timestamp', 'longitude', 'latitude']
# App Events: ['event_id', 'app_id', 'is_installed', 'is_active']
# Devices: ['device_id', 'phone_brand', 'device_model']
